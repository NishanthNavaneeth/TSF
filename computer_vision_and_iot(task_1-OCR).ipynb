# %% [markdown]
# <a href="https://colab.research.google.com/github/NishanthNavaneeth/TSF/blob/main/computer_vision_and_iot(task_1-OCR).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # #GRIP_OCTOBER21
#
# #NAME :- NISHANTH NAVANEETH
#
# #DOMAIN :- COMPUTER VISION AND IOT
#
# #TASK-1 :- OPTICAL CHARACTER RECOGNITION (OCR)

# %% [markdown]
# # #PIP installing Pytesseract and Tesseract-OCR libraries in Google Colab

# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tesseract-ocr is already the newest version (4.00~git2288-10f4998a-2).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.
# ...

# %% [markdown]
# # #importing libraries

# %%
import pytesseract #to extract text from an image
import cv2 #to handle the image
import PIL #to fetch path of an image

# %% [markdown]
# # #reading an image from local system

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-497ee85b-88b3-44a1-b912-9f8a298f3739" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-497ee85b-88b3-44a1-b912-9f8a298f3739">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving text aste.png to text aste (1).png

# %% [markdown]
# # #reading an image from local system

# %%
from google.colab.patches import cv2_imshow
img=cv2.imread('/content/text aste.png')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1123x646 at 0x7FAA30F73450>

# %% [markdown]
# # #extracting text from the image

# %%
from PIL import Image
image_path_in_colab="text aste.png"
extractedInformation = pytesseract.image_to_string(Image.open(image_path_in_colab))

# %% [markdown]
# # #printing the extracted text from the image

# %%
print(extractedInformation)
# Out:
# | am working on the program to extract text from the image. For that | tried with Tessaract and
# Ocropus libraries and | am able to convert simple plain text (black and white with simple font) from
# image to text string. For example:
#
# Adobe, the Adobe logo, Acrobat, the Acrobat logo, Acrobat Capture, Adobe Garamond, Adobe
# Intelligent Document Platform, Adobe PDF, Adobe Reader, Adobe Solutions Network, Aldus, Dis-
# tiller, ePaper, Extreme, FrameMaker, Illustrator, InDesign, Minion, Myriad, PageMaker, Photo-
# shop, Poetica, PostScript, and XMP are either registered trademarks or trademarks of Adobe
# Systems Incorporated in the United States and/or other countries. Microsoft and Windows are
# either registered trademarks or trademarks of Microsoft Corporation in the United States and/or
# other countries. Apple, Mac, Macintosh, and Power Macintosh are trademarks of Apple Computer,
# ...
